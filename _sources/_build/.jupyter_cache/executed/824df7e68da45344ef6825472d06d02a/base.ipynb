% %%
%cd matlab/convolution_demo
%dir
convolutiondemo
% Out:
% convolutiondemo is not found in the current folder or on the MATLAB path, but exists in:
%     /Users/eechris/code/src/github.com/cpjobling/eg-150-textbook/lti_systems/matlab/convolution_demo
%
% Change the MATLAB current folder or add its folder to the MATLAB path.

% %%
convolutiondemo % ignore warnings
% Out:
% convolutiondemo is not found in the current folder or on the MATLAB path, but exists in:
%     /Users/eechris/code/src/github.com/cpjobling/eg-150-textbook/lti_systems/matlab/convolution_demo
%
% Change the MATLAB current folder or add its folder to the MATLAB path.

% %%
syms t tau alpha
assume(alpha > 0)

x(t) = heaviside(t); % unit step function
subplot(211)
fplot(x(t)),title('x(t)'),ylim([0,1.25])
h(t) = exp(-alpha*t)*heaviside(t);
subplot(212)
fplot(subs(h(t),alpha,1)),title('h(t)')

% %%
y(t) = int(x(tau)*h(t - tau),tau,0,t)
% Out:
% $y(t) =-\frac{2\,{\mathrm{e}}^{-\frac{\alpha \,t}{2}} \,{\left(\frac{{\mathrm{e}}^{-\frac{\alpha \,t}{2}} }{2}-\frac{{\mathrm{e}}^{\frac{\alpha \,t}{2}} }{2}\right)}\,{\left(\frac{\textrm{sign}\left(t\right)}{2}+\frac{1}{2}\right)}}{\alpha }$

% %%
clf
ya(t) = subs(y(t),alpha,1)
fplot(ya(t))
% Out:
% $ya(t) =-2\,{\mathrm{e}}^{-\frac{t}{2}} \,{\left(\frac{{\mathrm{e}}^{-\frac{t}{2}} }{2}-\frac{{\mathrm{e}}^{t/2} }{2}\right)}\,{\left(\frac{\textrm{sign}\left(t\right)}{2}+\frac{1}{2}\right)}$

% %%
subplot(211)
fplot(subs(h(t),alpha,1)),title('h(t)'),ylim([0,1.25])
subplot(212)
fplot(x(t)),title('x(t)'),ylim([0,1.25])

% %%
y(t) = int(h(tau)*x(t - tau),tau,-Inf,Inf)
% Out:
% $y(t) =-\frac{2\,{\mathrm{e}}^{-\frac{\alpha \,t}{2}} \,{\left(\frac{{\mathrm{e}}^{-\frac{\alpha \,t}{2}} }{2}-\frac{{\mathrm{e}}^{\frac{\alpha \,t}{2}} }{2}\right)}\,{\left(\frac{\textrm{sign}\left(t\right)}{2}+\frac{1}{2}\right)}}{\alpha }$

% %%
clf
yb(t) = subs(y(t),alpha,1)
fplot(yb(t))
% Out:
% $yb(t) =-2\,{\mathrm{e}}^{-\frac{t}{2}} \,{\left(\frac{{\mathrm{e}}^{-\frac{t}{2}} }{2}-\frac{{\mathrm{e}}^{t/2} }{2}\right)}\,{\left(\frac{\textrm{sign}\left(t\right)}{2}+\frac{1}{2}\right)}$

% %%
x(t) = exp(t)*heaviside(-t);
subplot(211)
fplot(x(t)),,title('x(t)')
h(t) = exp(-1*t)*heaviside(t);
subplot(212)
fplot(h(t)),title('h(t)')

% %%
y(t) = int(x(tau)*h(t - tau),tau,-Inf,Inf)
% Out:
% $y(t) =\left\lbrace \begin{array}{cl}
% \frac{{\mathrm{e}}^{-t} }{2} & \;\textrm{if}\;\;0\le t\\
% \frac{{\mathrm{e}}^t }{2} & \;\textrm{if}\;\;t\le 0
% \end{array}\right.$

% %%
fplot(y(t)),title('y(t) = x(t) * y(t)')

% %%
x(t) = heaviside(t)-heaviside(t-3);
h(t) = heaviside(t)-heaviside(t-2);
subplot(121)
fplot(x(t),[-3,6]),grid,ylim([0,3]),ylabel('x(t)'),xlabel('t')
subplot(122)
fplot(h(t),[-3,6]),grid,ylim([0,3]),ylabel('h(t)'),xlabel('t')

% %%
y(t) = int(x(tau)*h(t - tau),tau,-Inf,Inf)
% Out:
% $y(t) =\textrm{heaviside}\left(t-5\right)\,{\left(t-5\right)}-\textrm{heaviside}\left(t-3\right)\,{\left(t-3\right)}-\textrm{heaviside}\left(t-2\right)\,{\left(t-2\right)}+t\,\textrm{heaviside}\left(t\right)$

% %%
clf
fplot(y(t),[-3,6]),grid,ylim([0,2.5]),ylabel('h(t)'),xlabel('t')
