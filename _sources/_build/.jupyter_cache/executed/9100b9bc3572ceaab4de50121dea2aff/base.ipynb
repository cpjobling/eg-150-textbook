% %%
syms t

% %%
T = 1; % period of periodic signal

% %%
x(t) = t * (heaviside(t) - heaviside(t-T));

% %%
fplot(x(t)),ylim([0 1.2]),grid,title('A Single period of x(t)'),xlabel('t')

% %%
signal1 = x(t + T)
% Out:
% $signal1 ={\left(t+1\right)}\,{\left(\textrm{heaviside}\left(t+1\right)-\textrm{heaviside}\left(t\right)\right)}$

% %%
fplot(signal1),ylim([0 1.2]),grid,title('A Single period of x(t+T)')

% %%
signal2 = x(t-2*T)
% Out:
% $signal2 ={\left(\textrm{heaviside}\left(t-2\right)-\textrm{heaviside}\left(t-3\right)\right)}\,{\left(t-2\right)}$

% %%
fplot(signal2),ylim([0 1.2]),grid,title('A Single period of x(t)')

% %%
periodic_signal = 0;
for m = 5:-1:-5
    periodic_signal = periodic_signal + x(t + m*T);
end
periodic_signal
% Out:
% $periodic_signal ={\left(t+1\right)}\,{\left(\textrm{heaviside}\left(t+1\right)-\textrm{heaviside}\left(t\right)\right)}+{\left(\textrm{heaviside}\left(t-1\right)-\textrm{heaviside}\left(t-2\right)\right)}\,{\left(t-1\right)}-{\left(\textrm{heaviside}\left(t+1\right)-\textrm{heaviside}\left(t+2\right)\right)}\,{\left(t+2\right)}+{\left(\textrm{heaviside}\left(t-2\right)-\textrm{heaviside}\left(t-3\right)\right)}\,{\left(t-2\right)}-{\left(\textrm{heaviside}\left(t+2\right)-\textrm{heaviside}\left(t+3\right)\right)}\,{\left(t+3\right)}+{\left(\textrm{heaviside}\left(t-3\right)-\textrm{heaviside}\left(t-4\right)\right)}\,{\left(t-3\right)}-{\left(\textrm{heaviside}\left(t+3\right)-\textrm{heaviside}\left(t+4\right)\right)}\,{\left(t+4\right)}+{\left(\textrm{heaviside}\left(t-4\right)-\textrm{heaviside}\left(t-5\right)\right)}\,{\left(t-4\right)}-{\left(\textrm{heaviside}\left(t+4\right)-\textrm{heaviside}\left(t+5\right)\right)}\,{\left(t+5\right)}+{\left(\textrm{heaviside}\left(t-5\right)-\textrm{heaviside}\left(t-6\right)\right)}\,{\left(t-5\right)}-t\,{\left(\textrm{heaviside}\left(t-1\right)-\textrm{heaviside}\left(t\right)\right)}$

% %%
fplot(periodic_signal,'g-',"LineWidth",2),...
    grid,ylabel('x(t)'),xlabel('t'),title('T = 1')
xlim([-3.00 3.00])
ylim([0 1.2])
