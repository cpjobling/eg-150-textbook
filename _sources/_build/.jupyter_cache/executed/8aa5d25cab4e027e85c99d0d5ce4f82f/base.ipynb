% %%
clear all
setappdata(0, "MKernel_plot_format", 'svg')
format compact

% %%
Ns = [2, 5]; Ds = [1, 5, 6];
[r,p,k] = residue(Ns, Ds)
% Out:
% r = 2×1 double
%     1.0000
%     1.0000
% p = 2×1 double
%    -3.0000
%    -2.0000
% k =
%      []

% %%
syms s t;
F1s = (2*s + 5)/(s^2 + 5*s + 6);
f1t = ilaplace(Fs)
fplot(f1t,[0,5]),title('Solution to Exercise 11.1'),grid,ylabel('f_1(t)'),xlabel('t [s]')
% Out:
% Unrecognized function or variable 'Fs'.

% %%
syms s;
factor(s^3 + 9*s^2 + 23*s + 15)
% Out:
% $ans =\left(\begin{array}{ccc}
% s+3 & s+5 & s+1
% \end{array}\right)$

% %%
F2s = (3*s^2 + 2*s + 5)/((s+1)*(s+3)*(s+5))
f2t = ilaplace(F2s)
fplot(f2t,[0,5]),grid,title('Solution to Exercise 11.2'),ylabel('f_2(t)'),xlabel('t [s]')
% Out:
% $F2s =\frac{3\,s^2 +2\,s+5}{{\left(s+1\right)}\,{\left(s+3\right)}\,{\left(s+5\right)}}$
% $f2t =\frac{3\,{\mathrm{e}}^{-t} }{4}-\frac{13\,{\mathrm{e}}^{-3\,t} }{2}+\frac{35\,{\mathrm{e}}^{-5\,t} }{4}$

% %%
Ns = [1 3]; Ds = conv([1 1],[1 4 8]) % conv of two vectors is polynomial multiplication
[r,p,k]=residue(Ns,Ds)
% Out:
% Ds = 1×4 double
%      1     5    12     8
% r =
%   -0.2000 - 0.1500i
%   -0.2000 + 0.1500i
%    0.4000 + 0.0000i
% p =
%   -2.0000 + 2.0000i
%   -2.0000 - 2.0000i
%   -1.0000 + 0.0000i
% k =
%      []

% %%
F3s = (s+3)/((s+1)*(s^2 + 4*s + 8))
f3t = ilaplace(F3s)
fplot(f3t,[0,10]),ylim([0,0.3]),grid,title('Solution to Exercise 11.3'),ylabel('f_3(t)'),xlabel('t [s]')
% Out:
% $F3s =\frac{s+3}{{\left(s+1\right)}\,{\left(s^2 +4\,s+8\right)}}$
% $f3t =\frac{2\,{\mathrm{e}}^{-t} }{5}-\frac{2\,{\mathrm{e}}^{-2\,t} \,{\left(\cos \left(2\,t\right)-\frac{3\,\sin \left(2\,t\right)}{4}\right)}}{5}$

% %%
F4s = (s + 3)/((s+2)*(s+1)^2)
f4t = ilaplace(F4s)
fplot(f4t,[0,10]),grid,ylim([0,0.6]),title('Solution to Exercise 11.4'),ylabel('f_4(t)'),xlabel('t [s]')
% Out:
% $F4s =\frac{s+3}{{{\left(s+1\right)}}^2 \,{\left(s+2\right)}}$
% $f4t ={\mathrm{e}}^{-2\,t} -{\mathrm{e}}^{-t} +2\,t\,{\mathrm{e}}^{-t}$

% %%
Ns = [1 3]
Ds = conv([1 2],conv([1 1],[1 1])) % (s + 2)*(s + 1)*(s + 1)
[r,p,k] = residue(Ns,Ds)
doc residue
% Out:
% Ns = 1×2 double
%      1     3
% Ds = 1×4 double
%      1     4     5     2
% r = 3×1 double
%     1.0000
%    -1.0000
%     2.0000
% p = 3×1 double
%    -2.0000
%    -1.0000
%    -1.0000
% k =
%      []

% %%
Ns = [1, 2, 2]; Ds = [1 1];
[r, p, k] = residue(Ns, Ds)
% Out:
% r = 1
% p = -1
% k = 1×2 double
%      1     1

% %%
syms s;
F6s = (s^2 + 2*s + 2)/(s + 1);
f6t = ilaplace(F6)
% Out:
% Unrecognized function or variable 'F6'.
